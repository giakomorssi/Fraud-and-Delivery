# %% [markdown]
# <a href="https://colab.research.google.com/github/giakomorssi/Deloitte_Project/blob/main/04_Results.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Results Prediction Delivery

# %%
# !rm -r Deloitte_Project
# !git clone https://github.com/giakomorssi/Deloitte_Project
# !pip install -q category_encoders
import sys
sys.path.append('/content/Deloitte_Project')
from functions import prediction_h5
from functions import prediction_pkl

prediction_h5('nn1.h5')
# Out:
# Cloning into 'Deloitte_Project'...
# remote: Enumerating objects: 225, done.
# remote: Counting objects: 100% (102/102), done.
# remote: Compressing objects: 100% (100/100), done.
# remote: Total 225 (delta 58), reused 2 (delta 2), pack-reused 123
# Receiving objects: 100% (225/225), 3.40 MiB | 17.34 MiB/s, done.
# Resolving deltas: 100% (116/116), done.
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 516)               57276
#
#  dense_1 (Dense)             (None, 256)               132352
#
#  dense_2 (Dense)             (None, 128)               32896
#
#  dense_3 (Dense)             (None, 64)                8256
#
#  dense_4 (Dense)             (None, 32)                2080
#
#  dense_5 (Dense)             (None, 16)                528
#
#  dense_6 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 233,405
# Trainable params: 233,405
# Non-trainable params: 0
# _________________________________________________________________
#
# Model:
#  None
#
# 1129/1129 [==============================] - 2s 2ms/step - loss: 0.4047 - mean_squared_error: 0.3665
# 1129/1129 [==============================] - 2s 1ms/step
# 1129/1129 [==============================] - 2s 2ms/step - loss: 0.4050 - mean_squared_error: 0.3668
# 1129/1129 [==============================] - 2s 2ms/step
# 1129/1129 [==============================] - 2s 2ms/step - loss: 0.4110 - mean_squared_error: 0.3728
# 1129/1129 [==============================] - 2s 1ms/step
# 1129/1129 [==============================] - 2s 2ms/step - loss: 0.4090 - mean_squared_error: 0.3709
# 1129/1129 [==============================] - 2s 1ms/step
# 1129/1129 [==============================] - 2s 2ms/step - loss: 0.4087 - mean_squared_error: 0.3705
# 1129/1129 [==============================] - 2s 1ms/step
#
#  rMSE Mean: 0.6078581363513151
# rMSE Std: 0.0020141328514649295
# Loss Mean: 0.4076692283153534
# Loss Std: 0.002448106712112535
# Within Threshold Mean: 0.6321404830489696
# Within Threshold Std: 0.0021796150152656323
#
# Class 0: 1011 instances, RMSE = 0.180128, Average Predicted Value = 0.015804
# Class 1: 949 instances, RMSE = 0.109406, Average Predicted Value = 0.925311
# Class 2: 11306 instances, RMSE = 0.390785, Average Predicted Value = 2.201987
# Class 3: 5738 instances, RMSE = 0.867954, Average Predicted Value = 3.015756
# Class 4: 5708 instances, RMSE = 0.240671, Average Predicted Value = 4.083539
# Class 5: 5558 instances, RMSE = 0.526796, Average Predicted Value = 5.168769
# Class 6: 5834 instances, RMSE = 0.963028, Average Predicted Value = 5.173755
# 1129/1129 [==============================] - 2s 2ms/step

# %%
# !rm -r Deloitte_Project
# !git clone https://github.com/giakomorssi/Deloitte_Project
# !pip install -q category_encoders
import sys
sys.path.append('/content/Deloitte_Project')
from functions import prediction_pkl

prediction_pkl()
# Out:
# Cloning into 'Deloitte_Project'...
# remote: Enumerating objects: 225, done.
# remote: Counting objects: 100% (102/102), done.
# remote: Compressing objects: 100% (100/100), done.
# remote: Total 225 (delta 58), reused 2 (delta 2), pack-reused 123
# Receiving objects: 100% (225/225), 3.40 MiB | 24.90 MiB/s, done.
# Resolving deltas: 100% (116/116), done.
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#
# Model:
# RandomForestRegressor()
#
#
#  rMSE Mean: 0.8208546976373355
# rMSE Std: 0.0
# Within Threshold Mean: 0.6323122091734987
# Within Threshold Std: 0.0022779620202694802
#
# Class 0: 1014 instances, RMSE = 0.170509, Average Predicted Value = 0.036154
# Class 1: 915 instances, RMSE = 0.065430, Average Predicted Value = 0.989639
# Class 2: 11421 instances, RMSE = 0.290660, Average Predicted Value = 2.037601
# Class 3: 5763 instances, RMSE = 0.953334, Average Predicted Value = 2.425596
# Class 4: 5701 instances, RMSE = 0.375539, Average Predicted Value = 3.901363
# Class 5: 5579 instances, RMSE = 0.817746, Average Predicted Value = 4.608371
# Class 6: 5711 instances, RMSE = 1.540686, Average Predicted Value = 4.628795

# %% [markdown]
# # Results Fraud Detection
#
# test on a part of test set not scaled

# %%
# !rm -r Deloitte_Project
# !git clone https://github.com/giakomorssi/Deloitte_Project
# !pip install -q category_encoders
import sys
sys.path.append('/content/Deloitte_Project')
from functions import fraud_detection

fraud_detection('voting_2.pkl')
# Out:
# Cloning into 'Deloitte_Project'...
# remote: Enumerating objects: 225, done.
# remote: Counting objects: 100% (102/102), done.
# remote: Compressing objects: 100% (100/100), done.
# remote: Total 225 (delta 58), reused 2 (delta 2), pack-reused 123
# Receiving objects: 100% (225/225), 3.40 MiB | 24.90 MiB/s, done.
# Resolving deltas: 100% (116/116), done.
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#
# Model:
#  VotingClassifier(estimators=[('rf',
#                               RandomForestClassifier(class_weight='balanced',
#                                                      max_depth=4)),
#                              ('lr',
#                               LogisticRegression(class_weight='balanced',
#                                                  max_iter=1000))],
#                  voting='soft')
#
# Iteration: 10
#
#  Fraud Recall: 0.9979, std: 0.0022
#  Suspected Recall: 0.6282, std: 0.0044
#  Regular Recall: 0.8793, std: 0.0039
#  Total: 0.8351, std: 0.0022
# Precisions [0.2616 0.93   0.7101]
#
#  Average Confusion Matrix:
# [[8.1030e+02 2.0000e-01 1.5000e+00]
#  [1.5828e+03 2.4874e+04 1.8326e+03]
#  [7.3890e+02 1.8641e+03 4.3980e+03]]

# %%
# !rm -r Deloitte_Project
# !git clone https://github.com/giakomorssi/Deloitte_Project
# !pip install -q category_encoders
import sys
sys.path.append('/content/Deloitte_Project')
from functions import fraud_detection

fraud_detection('voting_3.pkl')
# Out:
# Cloning into 'Deloitte_Project'...
# remote: Enumerating objects: 225, done.
# remote: Counting objects: 100% (102/102), done.
# remote: Compressing objects: 100% (100/100), done.
# remote: Total 225 (delta 58), reused 2 (delta 2), pack-reused 123
# Receiving objects: 100% (225/225), 3.40 MiB | 25.82 MiB/s, done.
# Resolving deltas: 100% (116/116), done.
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#
# Model:
#  VotingClassifier(estimators=[('rf',
#                               RandomForestClassifier(class_weight='balanced',
#                                                      max_depth=4)),
#                              ('dt',
#                               DecisionTreeClassifier(class_weight='balanced',
#                                                      max_depth=4)),
#                              ('lr',
#                               LogisticRegression(class_weight='balanced',
#                                                  max_iter=1000))],
#                  voting='soft')
#
# Iteration: 10
#
#  Fraud Recall: 0.991, std: 0.0044
#  Suspected Recall: 0.6119, std: 0.003
#  Regular Recall: 0.901, std: 0.0043
#  Total: 0.8346, std: 0.0029
# Precisions [0.2652 0.928  0.7843]
#
#  Average Confusion Matrix:
# [[8.0470e+02 4.5000e+00 2.8000e+00]
#  [1.5527e+03 2.5488e+04 1.2479e+03]
#  [6.8960e+02 2.0273e+03 4.2841e+03]]

# %%
# !rm -r Deloitte_Project
# !git clone https://github.com/giakomorssi/Deloitte_Project
# !pip install -q category_encoders
import sys
sys.path.append('/content/Deloitte_Project')
from functions import fraud_detection

fraud_detection('stacking.pkl')
# Out:
# Cloning into 'Deloitte_Project'...
# remote: Enumerating objects: 225, done.
# remote: Counting objects: 100% (102/102), done.
# remote: Compressing objects: 100% (100/100), done.
# remote: Total 225 (delta 58), reused 2 (delta 2), pack-reused 123
# Receiving objects: 100% (225/225), 3.40 MiB | 26.01 MiB/s, done.
# Resolving deltas: 100% (116/116), done.
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#
# Model:
#  StackingClassifier(estimators=[('rf',
#                                 RandomForestClassifier(class_weight='balanced',
#                                                        max_depth=4)),
#                                ('lr',
#                                 LogisticRegression(class_weight='balanced',
#                                                    max_iter=1000))],
#                    final_estimator=DecisionTreeClassifier())
#
# Iteration: 10
#
#  Fraud Recall: 0.5562, std: 0.0176
#  Suspected Recall: 0.676, std: 0.0059
#  Regular Recall: 0.9121, std: 0.0047
#  Total: 0.7148, std: 0.0068
# Precisions [0.5632 0.9269 0.6276]
#
#  Average Confusion Matrix:
# [[4.5160e+02 1.2700e+01 3.4770e+02]
#  [4.9000e+00 2.5804e+04 2.4806e+03]
#  [3.2130e+02 1.9471e+03 4.7326e+03]]

# %%
# !rm -r Deloitte_Project
# !git clone https://github.com/giakomorssi/Deloitte_Project
# !pip install -q category_encoders
import sys
sys.path.append('/content/Deloitte_Project')
from functions import fraud_detection

fraud_detection('voting_stack_voting.pkl')
# Out:
# Cloning into 'Deloitte_Project'...
# remote: Enumerating objects: 225, done.
# remote: Counting objects: 100% (104/104), done.
# remote: Compressing objects: 100% (102/102), done.
# remote: Total 225 (delta 59), reused 2 (delta 2), pack-reused 121
# Receiving objects: 100% (225/225), 3.40 MiB | 27.89 MiB/s, done.
# Resolving deltas: 100% (116/116), done.
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#
# Model:
#  VotingClassifier(estimators=[('voting_3',
#                               VotingClassifier(estimators=[('rf',
#                                                             RandomForestClassifier(class_weight='balanced',
#                                                                                    max_depth=4)),
#                                                            ('dt',
#                                                             DecisionTreeClassifier(class_weight='balanced',
#                                                                                    max_depth=4)),
#                                                            ('lr',
#                                                             LogisticRegression(class_weight='balanced',
#                                                                                max_iter=1000))],
#                                                voting='soft')),
#                              ('stack',
#                               StackingClassifier(estimators=[('rf',
#                                                               RandomForestClassifier(class_weight='balanced',
#                                                                                      max_depth=4)),
#                                                              ('lr',
#                                                               LogisticRegression(class_weight='balanced',
#                                                                                  max_iter=1000))],
#                                                  final_estimator=DecisionTreeClassifier()))])
#
# Iteration: 10
#
#  Fraud Recall: 0.9959, std: 0.0021
#  Suspected Recall: 0.5803, std: 0.0039
#  Regular Recall: 0.9301, std: 0.0026
#  Total: 0.8355, std: 0.0023
# Precisions [0.2653 0.922  0.9032]
#
#  Average Confusion Matrix:
# [[8.0870e+02 2.0000e+00 1.3000e+00]
#  [1.5517e+03 2.6311e+04 4.2620e+02]
#  [7.3310e+02 2.2049e+03 4.0630e+03]]
